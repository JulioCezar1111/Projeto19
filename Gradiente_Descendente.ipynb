# %% [markdown]
# <a href="https://colab.research.google.com/github/JulioCezar1111/Projeto19/blob/main/Gradiente_Descendente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **RECEITA DE TREINAMENTO PARA O torch**
#  1 - DESIGN DO MODELO (INPUT, OUTPUT, FORWARD PASS)
#
#  2 - DEFINIÇAO DA FUNÇÃO DE CUSTO E OTIMIZADOR
#
#  3 - LOOP DE TREINAMENTO:
#
#   FORWARD PASS: CALCULAR A PREDIÇÃO E O CUSTO
#
#   BACKWARPASS: CALCULAR OS GRADIENTES
#
#   ATUALIZAR OS PESOS

# %% [markdown]
# # **Importar Bibliotecas**

# %%
import torch 
import time
import torch.nn as nn
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
from torch.autograd import variable

# %% [markdown]
# # **Preparação da DATA**

# %%
x_numpy, y_numpy = datasets.make_regression(n_samples=100, n_features=1, noise=20, random_state=1)

x = torch.from_numpy(x_numpy.astype(np.float32)) # Converte
y = torch.from_numpy(y_numpy.astype(np.float32))
y = y.view(y.shape[0], 1) # alterando a dimensão

print(x.shape)
print(y.shape)

plt.plot(x_numpy, y_numpy, 'ro')
# Out:
# torch.Size([100, 1])
# torch.Size([100, 1])

# %% [markdown]
# # **DEFINIÇÃO DE MODELO**

# %%
input_size = 1 # dados de entrada
output_size = 1 # dados de saida
model = nn.Linear(input_size, output_size) # Criar o modelo

# %% [markdown]
# # **DEFINIÇÃO DA FUNÇAO DE CUSTO E OTIMIZADOR**

# %%
learning_rate = 0.01 # Normaliza o passo
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate) # Criar o otimizador
print(model.parameters())
# Out:
# <generator object Module.parameters at 0x7f537e28f8d0>

# %% [markdown]
# # **LOOP DE TREINAMENTO**

# %%
num_epochs = 1000 # interação que ira fazer para achar os valores dos parametros
contador_custo = []
epochs_ = []
for epoch in range(num_epochs):
  #forward pass and loos
  y_hat = model(x) # cria o modelo (começo aleatorio)
  loss = criterion(y_hat, y) # fazer o calculo do custo
  contador_custo.append(loss.detach().numpy()) # lista para monitorar a queda e intensidade 
  epochs_.append(range(num_epochs))
  
  #backward pass (calcular gradientes)
  loss.backward() # Faz os calculos das derivadas parciais

  #update (atualizar os pesos)
  optimizer.step() # atualiza os pesos

  if (epoch <= 10): # condição para mostrar em 10 em 10
    print('Epoch: ', epoch) # quantas vezes ele fez os calculos
    print('Custo: {:.20f}'.format(loss.item())) # o custo atual
    print('Coeficientes: ')
    print('m: {:.20f}'.format(model.weight.data.detach().item()))
    print('m (gradiente): {:.20f}'.format(model.weight.grad.detach().item()))
    print('b: {:.20f}'.format(model.bias.data.detach().item()))
    print('b (gradiente): {:.20f}'.format(model.bias.grad.detach().item()))
    #for p in model.parameters():
    #  print('{:.2f}'.format(p.data.detach().item()))
    #  print('{:.2f}'.format(p.grad.detach().item()))

    #plotar grafico
    previsao_final = y_hat.detach().numpy()
    plt.plot(x_numpy, y_numpy, 'ro') 
    plt.plot(x_numpy, previsao_final, 'b')
    plt.show()
    time.sleep(1)

  if (epoch >= 990):
    print('Epoch: ', epoch) # quantas vezes ele fez os calculos
    print('Custo: {:.20f}'.format(loss.item())) # o custo atual
    print('Coeficientes: ')
    print('m: {:.20f}'.format(model.weight.data.detach().item()))
    print('m (gradiente): {:.20f}'.format(model.weight.grad.detach().item()))
    print('b: {:.20f}'.format(model.bias.data.detach().item()))
    print('b (gradiente): {:.20f}'.format(model.bias.grad.detach().item()))
    previsao_final = y_hat.detach().numpy()
    plt.plot(x_numpy, y_numpy, 'ro') 
    plt.plot(x_numpy, previsao_final, 'b')
    plt.show()
    time.sleep(1)

  #limpar o otimizador
  optimizer.zero_grad()
# Out:
# Epoch:  0
# Custo: 5888.04101562500000000000
# Coeficientes:
# m: 0.34109029173851013184
# m (gradiente): -131.98362731933593750000
# b: -0.56691300868988037109
# b (gradiente): -19.74976158142089843750
# Epoch:  1
# Custo: 5711.38574218750000000000
# Coeficientes:
# m: 1.63990867137908935547
# m (gradiente): -129.88183593750000000000
# b: -0.37496453523635864258
# b (gradiente): -19.19484901428222656250
# Epoch:  2
# Custo: 5540.40332031250000000000
# Coeficientes:
# m: 2.91804671287536621094
# m (gradiente): -127.81380462646484375000
# b: -0.18842874467372894287
# b (gradiente): -18.65357971191406250000
# Epoch:  3
# Custo: 5374.90917968750000000000
# Coeficientes:
# m: 4.17583608627319335938
# m (gradiente): -125.77893829345703125000
# b: -0.00717234006151556969
# b (gradiente): -18.12564086914062500000
# Epoch:  4
# Custo: 5214.72656250000000000000
# Coeficientes:
# m: 5.41360425949096679688
# m (gradiente): -123.77682495117187500000
# b: 0.16893491148948669434
# b (gradiente): -17.61072540283203125000
# Epoch:  5
# Custo: 5059.68261718750000000000
# Coeficientes:
# m: 6.63167238235473632812
# m (gradiente): -121.80680847167968750000
# b: 0.34002026915550231934
# b (gradiente): -17.10853576660156250000
# Epoch:  6
# Custo: 4909.60791015625000000000
# Coeficientes:
# m: 7.83035659790039062500
# m (gradiente): -119.86842346191406250000
# b: 0.50620806217193603516
# b (gradiente): -16.61877822875976562500
# Epoch:  7
# Custo: 4764.34472656250000000000
# Coeficientes:
# m: 9.00996780395507812500
# m (gradiente): -117.96115112304687500000
# b: 0.66761970520019531250
# b (gradiente): -16.14116287231445312500
# Epoch:  8
# Custo: 4623.73583984375000000000
# Coeficientes:
# m: 10.17081260681152343750
# m (gradiente): -116.08445739746093750000
# b: 0.82437384128570556641
# b (gradiente): -15.67541122436523437500
# Epoch:  9
# Custo: 4487.62988281250000000000
# Coeficientes:
# m: 11.31319141387939453125
# m (gradiente): -114.23790740966796875000
# b: 0.97658634185791015625
# b (gradiente): -15.22124862670898437500
# Epoch:  10
# Custo: 4355.88134765625000000000
# Coeficientes:
# m: 12.43740081787109375000
# m (gradiente): -112.42095947265625000000
# b: 1.12437033653259277344
# b (gradiente): -14.77840518951416015625
# Epoch:  990
# Custo: 332.56756591796875000000
# Coeficientes:
# m: 82.48426055908203125000
# m (gradiente): -0.00037208542926236987
# b: 4.05405473709106445312
# b (gradiente): 0.00002348423004150391
# Epoch:  991
# Custo: 332.56756591796875000000
# Coeficientes:
# m: 82.48426055908203125000
# m (gradiente): -0.00037208542926236987
# b: 4.05405473709106445312
# b (gradiente): 0.00002348423004150391
# Epoch:  992
# Custo: 332.56756591796875000000
# Coeficientes:
# m: 82.48426055908203125000
# m (gradiente): -0.00037208542926236987
# b: 4.05405473709106445312
# b (gradiente): 0.00002348423004150391
# Epoch:  993
# Custo: 332.56756591796875000000
# Coeficientes:
# m: 82.48426055908203125000
# m (gradiente): -0.00037208542926236987
# b: 4.05405473709106445312
# b (gradiente): 0.00002348423004150391
# Epoch:  994
# Custo: 332.56756591796875000000
# Coeficientes:
# m: 82.48426055908203125000
# m (gradiente): -0.00037208542926236987
# b: 4.05405473709106445312
# b (gradiente): 0.00002348423004150391
# Epoch:  995
# Custo: 332.56756591796875000000
# Coeficientes:
# m: 82.48426055908203125000
# m (gradiente): -0.00037208542926236987
# b: 4.05405473709106445312
# b (gradiente): 0.00002348423004150391
# Epoch:  996
# Custo: 332.56756591796875000000
# Coeficientes:
# m: 82.48426055908203125000
# m (gradiente): -0.00037208542926236987
# b: 4.05405473709106445312
# b (gradiente): 0.00002348423004150391
# Epoch:  997
# Custo: 332.56756591796875000000
# Coeficientes:
# m: 82.48426055908203125000
# m (gradiente): -0.00037208542926236987
# b: 4.05405473709106445312
# b (gradiente): 0.00002348423004150391
# Epoch:  998
# Custo: 332.56756591796875000000
# Coeficientes:
# m: 82.48426055908203125000
# m (gradiente): -0.00037208542926236987
# b: 4.05405473709106445312
# b (gradiente): 0.00002348423004150391
# Epoch:  999
# Custo: 332.56756591796875000000
# Coeficientes:
# m: 82.48426055908203125000
# m (gradiente): -0.00037208542926236987
# b: 4.05405473709106445312
# b (gradiente): 0.00002348423004150391
# [array(5888.041, dtype=float32), array(5711.3857, dtype=float32), array(5540.4033, dtype=float32), array(5374.909, dtype=float32), array(5214.7266, dtype=float32), array(5059.6826, dtype=float32), array(4909.608, dtype=float32), array(4764.3447, dtype=float32), array(4623.736, dtype=float32), array(4487.63, dtype=float32), array(4355.8813, dtype=float32), array(4228.3496, dtype=float32), array(4104.8975, dtype=float32), array(3985.3936, dtype=float32), array(3869.71, dtype=float32), array(3757.723, dtype=float32), array(3649.3135, dtype=float32), array(3544.3662, dtype=float32), array(3442.769, dtype=float32), array(3344.4138, dtype=float32), array(3249.196, dtype=float32), array(3157.0146, dtype=float32), array(3067.7725, dtype=float32), array(2981.3735, dtype=float32), array(2897.7268, dtype=float32), array(2816.7441, dtype=float32), array(2738.339, dtype=float32), array(2662.4294, dtype=float32), array(2588.9346, dtype=float32), array(2517.777, dtype=float32), array(2448.8818, dtype=float32), array(2382.1765, dtype=float32), array(2317.5903, dtype=float32), array(2255.0554, dtype=float32), array(2194.5059, dtype=float32), array(2135.879, dtype=float32), array(2079.1118, dtype=float32), array(2024.1453, dtype=float32), array(1970.922, dtype=float32), array(1919.3861, dtype=float32), array(1869.4836, dtype=float32), array(1821.162, dtype=float32), array(1774.371, dtype=float32), array(1729.0615, dtype=float32), array(1685.1863, dtype=float32), array(1642.6996, dtype=float32), array(1601.557, dtype=float32), array(1561.7156, dtype=float32), array(1523.134, dtype=float32), array(1485.7719, dtype=float32), array(1449.5903, dtype=float32), array(1414.5519, dtype=float32), array(1380.62, dtype=float32), array(1347.7595, dtype=float32), array(1315.9363, dtype=float32), array(1285.1171, dtype=float32), array(1255.2703, dtype=float32), array(1226.3649, dtype=float32), array(1198.3708, dtype=float32), array(1171.2594, dtype=float32), array(1145.0021, dtype=float32), array(1119.5723, dtype=float32), array(1094.9432, dtype=float32), array(1071.0901, dtype=float32), array(1047.9878, dtype=float32), array(1025.6125, dtype=float32), array(1003.9414, dtype=float32), array(982.9522, dtype=float32), array(962.6228, dtype=float32), array(942.93286, dtype=float32), array(923.8619, dtype=float32), array(905.3904, dtype=float32), array(887.4991, dtype=float32), array(870.16986, dtype=float32), array(853.38477, dtype=float32), array(837.1269, dtype=float32), array(821.3792, dtype=float32), array(806.12604, dtype=float32), array(791.3514, dtype=float32), array(777.0402, dtype=float32), array(763.17773, dtype=float32), array(749.75006, dtype=float32), array(736.74335, dtype=float32), array(724.1442, dtype=float32), array(711.94, dtype=float32), array(700.118, dtype=float32), array(688.6665, dtype=float32), array(677.5735, dtype=float32), array(666.8279, dtype=float32), array(656.4187, dtype=float32), array(646.3352, dtype=float32), array(636.5672, dtype=float32), array(627.10474, dtype=float32), array(617.9384, dtype=float32), array(609.05865, dtype=float32), array(600.45654, dtype=float32), array(592.1232, dtype=float32), array(584.0504, dtype=float32), array(576.22986, dtype=float32), array(568.6537, dtype=float32), array(561.31415, dtype=float32), array(554.20374, dtype=float32), array(547.31537, dtype=float32), array(540.642, dtype=float32), array(534.177, dtype=float32), array(527.91376, dtype=float32), array(521.84595, dtype=float32), array(515.9675, dtype=float32), array(510.27228, dtype=float32), array(504.7546, dtype=float32), array(499.4091, dtype=float32), array(494.2302, dtype=float32), array(489.2128, dtype=float32), array(484.3516, dtype=float32), array(479.6419, dtype=float32), array(475.07892, dtype=float32), array(470.6581, dtype=float32), array(466.37497, dtype=float32), array(462.2253, dtype=float32), array(458.2047, dtype=float32), array(454.3094, dtype=float32), array(450.5353, dtype=float32), array(446.87854, dtype=float32), ar ...

# %% [markdown]
# # **PLOTANDO O GRÁFICO DA FUNÇÃO DE CUSTO**

# %%
print("GRÁFICO DA FUNÇÃO DE CUSTO")
plt.plot(contador_custo, 'r')
plt.show()
# Out:
# GRÁFICO DA FUNÇÃO DE CUSTO
